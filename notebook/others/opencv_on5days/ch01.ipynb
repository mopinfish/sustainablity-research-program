# %%
# !pip install opencv-contrib-python
# Out:
# ...
#      |████████████████████████████████| 55.7 MB 64 kB/s  eta 0:00:01    |                                | 153 kB 652 kB/s eta 0:01:26     |██████████▊                     | 18.6 MB 1.7 MB/s eta 0:00:23     |████████████████▊               | 29.2 MB 1.9 MB/s eta 0:00:14     |████████████████████████▍       | 42.5 MB 2.1 MB/s eta 0:00:07     |██████████████████████████▉     | 46.8 MB 1.3 MB/s eta 0:00:08     |███████████████████████████▍    | 47.7 MB 1.1 MB/s eta 0:00:08     |████████████████████████████▉   | 50.3 MB 375 kB/s eta 0:00:15     |███████████████████████████████▎| 54.5 MB 1.3 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !sudo apt update -y
# !sudo apt install -y libgl1-mesa-dev
# Out:
# Get:1 http://security.ubuntu.com/ubuntu focal-security InRelease [109 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal InRelease [265 kB]
# Get:3 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [489 kB]33m
# Get:4 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal-backports InRelease [101 kB]m
# Get:6 http://archive.ubuntu.com/ubuntu focal/restricted amd64 Packages [33.4 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/main amd64 Packages [1,275 kB]
# Get:8 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [1,165 B]
# Get:9 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [643 kB]
# Get:10 http://security.ubuntu.com/ubuntu focal-security/restricted amd64 Packages [103 kB]33m
# Get:11 http://archive.ubuntu.com/ubuntu focal/universe amd64 Packages [11.3 MB]
# Get:12 http://archive.ubuntu.com/ubuntu focal/multiverse amd64 Packages [177 kB]
# ...

# %%
import os
import pprint
import time
import urllib.error
import urllib.request

def download_file(url, dst_path):
    try:
        with urllib.request.urlopen(url) as web_file:
            data = web_file.read()
            with open(dst_path, mode='wb') as local_file:
                local_file.write(data)
    except urllib.error.URLError as e:
        print(e)

# %%
dst_dir = 'data'
if not os.path.isdir(dst_dir):
  os.makedirs(dst_dir)

# %%
url = 'https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.pakutaso.com%2F20161015293post-9303.html&psig=AOvVaw3D_-n8VwCz1BnfCxPH_E0D&ust=1607412118427000&source=images&cd=vfe&ved=0CAIQjRxqFwoTCNiGgfaqu-0CFQAAAAAdAAAAABAD'
dst_file = 'data/sample.jpg'
download_file(url, dst_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e0dfa2244563> in <module>
#       1 url = 'https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.pakutaso.com%2F20161015293post-9303.html&psig=AOvVaw3D_-n8VwCz1BnfCxPH_E0D&ust=1607412118427000&source=images&cd=vfe&ved=0CAIQjRxqFwoTCNiGgfaqu-0CFQAAAAAdAAAAABAD'
#       2 dst_file = 'data/sample.jpg'
# ----> 3 download_file(url, dst_file)
#
# NameError: name 'download_file' is not defined

# %%
# 画像の読み込み
import cv2
img = cv2.imread(dst_file, cv2.IMREAD_COLOR)
cv2.imshow('sample01', img)
