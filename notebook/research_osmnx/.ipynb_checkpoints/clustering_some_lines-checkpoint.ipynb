# %%
import networkx as nx
import osmnx as ox
import requests
import sys,os,os.path
import pandas as pd
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

ox.config(use_cache=True, log_console=True)
ox.__version__
# Out:
# '0.12.1'

# %%
stations = pd.read_csv('../../data/stations.csv')

# %%
stations.head()
# Out:
#    station_cd  station_g_cd station_name  station_name_k  station_name_r  \
# 0     1110101       1110101           函館             NaN             NaN
# 1     1110102       1110102          五稜郭             NaN             NaN
# 2     1110103       1110103           桔梗             NaN             NaN
# 3     1110104       1110104          大中山             NaN             NaN
# 4     1110105       1110105           七飯             NaN             NaN
#
#    line_cd  pref_cd      post           address         lon        lat  \
# 0    11101        1  040-0063    北海道函館市若松町１２-１３  140.726413  41.773709
# 1    11101        1  041-0813           函館市亀田本町  140.733539  41.803557
# 2    11101        1  041-0801  北海道函館市桔梗３丁目４１-３６  140.722952  41.846457
# 3    11101        1  041-1121       亀田郡七飯町大字大中山  140.713580  41.864641
# 4    11101        1  041-1111         亀田郡七飯町字本町  140.688556  41.886971
#
#      open_ymd   close_ymd  e_status   e_sort
# 0  1902-12-10  0000-00-00         0  1110101
# 1  0000-00-00  0000-00-00         0  1110102
# 2  1902-12-10  0000-00-00         0  1110103
# 3  0000-00-00  0000-00-00         0  1110104
# 4  0000-00-00  0000-00-00         0  1110105

# %%
# 日本語・ローマ字変換ライブラリ `pykakasi` をインストール
# !pip install git+https://github.com/miurahr/pykakasi
# Out:
# Collecting git+https://github.com/miurahr/pykakasi
#   Cloning https://github.com/miurahr/pykakasi to /tmp/pip-req-build-zbcwlci6
#   Running command git clone -q https://github.com/miurahr/pykakasi /tmp/pip-req-build-zbcwlci6
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied (use --upgrade to upgrade): pykakasi==2.0.0 from git+https://github.com/miurahr/pykakasi in /opt/conda/lib/python3.8/site-packages
# Requirement already satisfied: klepto in /opt/conda/lib/python3.8/site-packages (from pykakasi==2.0.0) (0.1.9)
# Requirement already satisfied: dill>=0.3.2 in /opt/conda/lib/python3.8/site-packages (from klepto->pykakasi==2.0.0) (0.3.2)
# Requirement already satisfied: pox>=0.2.8 in /opt/conda/lib/python3.8/site-packages (from klepto->pykakasi==2.0.0) (0.2.8)
# Building wheels for collected packages: pykakasi
#   Building wheel for pykakasi (PEP 517) ... done
#   Created wheel for pykakasi: filename=pykakasi-2.0.0-py3-none-any.whl size=1239818 sha256=6fc92fcc19b51f00793dd3cd458d1a993ccb1d0faa8c11944f20dde769300074
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1x1w26tl/wheels/62/49/c7/6c3498f4d54697dd2876d998349269c7b64871f871ee1180c7
# Successfully built pykakasi

# %%
from pykakasi import kakasi

kakasi = kakasi()

kakasi.setMode('H', 'a')
kakasi.setMode('K', 'a')
kakasi.setMode('J', 'a')

conv = kakasi.getConverter()

# %%
# 駅名のローマ字名を付与
stations['station_name_roman'] = stations['station_name'].apply(lambda name: conv.do(name))
stations
# Out:
#        station_cd  station_g_cd station_name  station_name_k  station_name_r  \
# 0         1110101       1110101           函館             NaN             NaN
# 1         1110102       1110102          五稜郭             NaN             NaN
# 2         1110103       1110103           桔梗             NaN             NaN
# 3         1110104       1110104          大中山             NaN             NaN
# 4         1110105       1110105           七飯             NaN             NaN
# ...           ...           ...          ...             ...             ...
# 10850     9992719       9992719        てだこ浦西             NaN             NaN
# 10851     9992801       1190202      九州鉄道記念館             NaN             NaN
# 10852     9992802       9992802        出光美術館             NaN             NaN
# 10853     9992803       9992803     ノーフォーク広場             NaN             NaN
# 10854     9992804       9992804      関門海峡めかり             NaN             NaN
#
#        line_cd  pref_cd      post           address         lon        lat  \
# 0        11101        1  040-0063    北海道函館市若松町１２-１３  140.726413  41.773709
# 1        11101        1  041-0813           函館市亀田本町  140.733539  41.803557
# 2        11101        1  041-0801  北海道函館市桔梗３丁目４１-３６  140.722952  41.846457
# 3        11101        1  041-1121       亀田郡七飯町大字大中山  140.713580  41.864641
# 4        11101        1  041-1111         亀田郡七飯町字本町  140.688556  41.886971
# ...        ...      ...       ...               ...         ...        ...
# 10850    99927       47  901-2102     沖縄県浦添市前田三丁目21  127.741861  26.241778
# 10851    99928       40  800-0000        福岡県北九州市門司区  130.962439  33.944392
# 10852    99928       40  800-0000        福岡県北九州市門司区  130.965292  33.947792
# 10853    99928       40  801-0854     福岡県北九州市門司区旧門司  130.964254  33.955973
# 10854    99928       40  801-0855      福岡県北九州市門司区門司  130.967347  33.960627
#
#          open_ymd   close_ymd  e_status   e_sort        station_name_roman
# 0      1902-12-10  0000-00-00         0  1110101                  hakodate
# 1      0000-00-00  0000-00-00         0  1110102                goryoukaku
# 2      1902-12-10  0000-00-00         0  1110103                    kikyou
# 3      0000-00-00  0000-00-00         0  1110104               daichuuyama
# 4      0000-00-00  0000-00-00         0  1110105               shichimeshi
# ...           ...         ...       ...      ...                       ...
# 10850  2019-10-01  0000-00-00         0  9992719            tedakouranishi
# 10851  0000-00-00  0000-00-00         0  9992801  kyuushuutetsudoukinenkan
# 10852  0000-00-00  0000-00-00         0  9992802        idemitsubijutsukan
# 10853  0000-00-00  0000-00-00         0  9992803            noofookuhiroba
# 10854  0000-00-00  0000-00-00         0  9992804       kanmonkaikyoumekari
#
# [10855 rows x 16 columns]

# %%
target_stations = stations[(stations['line_cd'] == 11312) | (stations['line_cd'] == 24001)]

# %%
import folium

# %%
center_lat, center_lon = (35.651820534474,139.54461236426)

_map = folium.Map(location=[center_lat, center_lon], zoom_start=12)

for _, station in target_stations.iterrows():
    color = 'red' if station['line_cd'] == 11312 else 'pink'
    folium.Marker([station.lat, station.lon], popup=str(station['station_name_roman']), icon=folium.Icon(color=color)).add_to(_map)

_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#駅の800m範囲内のグラフ構造の配列を取得
def get_stats(data):
    wurster_hall = (data['lat'], data['lon'])
    one_mile = 800 #meters
    G = ox.graph_from_point(wurster_hall, distance=one_mile, network_type='drive')

    # what sized area does our network cover in square meters?
    G_proj = ox.project_graph(G)
    nodes_proj = ox.graph_to_gdfs(G_proj, edges=False)
    graph_area_m = nodes_proj.unary_union.convex_hull.area
    
    # show some basic stats about the network
# 5495                       299                     124.076155
# 5496                       354                     144.826746
# 5497                       345                     146.023073
# 5498                       344                     152.306731
# 5499                       366                     147.007945
# 5500                       285                     147.695349
# 5501                       281                     116.984472
# 5502                       244                     121.550965
# 5503                       361                     152.512062
# 5504                       370                     167.393460
# 5505                       422                     181.025649
# 5506                       329                     132.670536
# 5507                       411                     173.049928
# 5508                       419                     168.375936

# %%
stats_list[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-4cfbb9483ca0> in <module>
# ----> 1 stats_list[0]
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0

# %%
target_stations_with_stats = pd.concat([target_stations, stats_list], axis=1)

# %%
target_stations_with_stats.to_csv('../../data/target_stations_with_stats')

# %%
target_stations_with_stats = pd.read_csv('../../data/target_stations_with_stats.csv')

# %%
# 路線ごとの交差点数、道路数のグラフ化
ax = None
colors = {11312: 'red', 24001: 'pink'}
for i, station in target_stations_with_stats.groupby('line_cd'):
    station.plot.scatter(x='n', y='m', color=colors[i], label='cluster{i}', ax=ax)

# %%
plt.hist([chuo_stations['n'], keio_stations['n']], bins = 20, color=['red', 'pink'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-384cd85e5aed> in <module>
# ----> 1 plt.hist([chuo_stations['n'], keio_stations['n']], bins = 20, color=['red', 'pink'])
#
# NameError: name 'chuo_stations' is not defined

# %%
plt.hist([chuo_stations['m'], keio_stations['m']], bins = 20, color=['red', 'pink'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-0300fa4df28c> in <module>
# ----> 1 plt.hist([chuo_stations['m'], keio_stations['m']], bins = 20, color=['red', 'pink'])
#
# NameError: name 'chuo_stations' is not defined

# %%
# k-means法を使うためのインポート
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# データの列の絞り込み
stations_sub = target_stations_with_stats[['n','m']]

# 標準化
sc = StandardScaler()
sc.fit(stations_sub)
stations_sub_std = sc.transform(stations_sub)

# %%
# KMeansクラスの初期化
kmeans = KMeans(init='random', n_clusters=2, random_state=0)

# クラスターの重心を計算
kmeans.fit(stations_sub_std)

# クラスター番号をpandasのSeriesオブジェクトに変換
labels = pd.Series(kmeans.labels_, name='cluster_number', index=target_stations_with_stats.index)

# クラスター番号と件数を表示
print(labels.value_counts(sort=False))

# グラフを描画
ax = labels.value_counts(sort=False).plot(kind='bar')
ax.set_xlabel('cluster number')
ax.set_ylabel('count')
# Out:
# 0    43
# 1    13
# Name: cluster_number, dtype: int64
# Text(0, 0.5, 'count')

# %%
# エルボー方による推定。クラスター数を1から20に増やして、それぞれの距離の総和を求める
dist_list =[]
for i in range(1,20):
    kmeans= KMeans(n_clusters=i, init='random', random_state=0)
    kmeans.fit(stations_sub_std)
    dist_list.append(kmeans.inertia_)
    
# グラフを表示
plt.plot(range(1,20), dist_list,marker='+')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
# Out:
# Text(0, 0.5, 'Distortion')

# %%
# 駅のデータにクラスター番号のデータを結合
stations_with_cluster = pd.concat([target_stations_with_stats, pd.Series(labels, index=target_stations_with_stats.index)], axis=1)

# 先頭の5行を表示
stations_with_cluster.head()
# Out:
#    Unnamed: 0  station_cd  station_g_cd station_name  station_name_k  \
# 0        1504     1131201       1130101           東京             NaN
# 1        1505     1131202       1130223           神田             NaN
# 2        1506     1131203       1131203         御茶ノ水             NaN
# 3        1507     1131207       1131102          四ツ谷             NaN
# 4        1508     1131211       1130208           新宿             NaN
#
#    station_name_r  line_cd  pref_cd      post            address  ...  \
# 0             NaN    11312       13  100-0005      東京都千代田区丸の内一丁目  ...
# 1             NaN    11312       13  101-0044  東京都千代田区鍛冶町二丁目13-1  ...
# 2             NaN    11312       13  101-0062       千代田区神田駿河台２丁目  ...
# 3             NaN    11312       13  160-0004        東京都新宿区四谷一丁目  ...
# 4             NaN    11312       13  160-0022    東京都新宿区新宿三丁目38-1  ...
#
#    street_segments_count  node_density_km intersection_density_km  \
# 0                    687       189.776780              187.564929
# 1                   1566       401.974424              396.166744
# 2                   1737       439.250321              427.732907
# 3                    663       202.387111              169.478638
# 4                   1081       291.609617              278.503567
#
#   edge_density_km  street_density_km  circuity_avg self_loop_proportion  \
# 0    26579.884081       22730.444358      1.013870             0.001239
# 1    43475.857491       35573.377567      1.010249             0.000515
# 2    44209.465308       32228.566100      1.007648             0.000000
# 3    28917.003433       18097.028930      1.041710             0.000000
# 4    36083.913658       24834.827357      1.023062             0.000000
#
#    clean_intersection_count  clean_intersection_density_km  cluster_number
# 0                       241                     106.611198               0
# 1                       511                     211.980321               0
# 2                       543                     215.653638               1
# 3                       255                     104.895759               0
# 4                       397                     162.596935               0
#
# [5 rows x 38 columns]

# %%
stations_0 = stations_with_cluster[stations_with_cluster['cluster_number'] == 0]
stations_1 = stations_with_cluster[stations_with_cluster['cluster_number'] == 1]
# クラスタリング結果のグラフ化
ax = None
colors = ['red', 'pink']
for i, station in stations_with_cluster.groupby('cluster_number'):
    station.plot.scatter(x='n', y='m', color=colors[i], label='cluster{i}', ax=ax)

# %%
# クラスタ番号と年齢層を軸に集計し、年齢層を列に設定
cross_cluster_line_cd = stations_with_cluster.groupby(['cluster_number', 'line_cd']).size().unstack().fillna(0)
cross_cluster_line_cd
# Out:
# line_cd         11312  24001
# cluster_number
# 0                  18     25
# 1                   6      7

# %%
sns.heatmap(cross_cluster_line_cd.apply(lambda x : x/x.sum(), axis=1), cmap='Blues')

# %%
print([station['station_name'] for _, station in stations_with_cluster.iterrows() if (station['cluster_number'] == 0)])
# Out:
# ['東京', '神田', '四ツ谷', '新宿', '西荻窪', '吉祥寺', '三鷹', '武蔵境', '東小金井', '国分寺', '西国分寺', '国立', '立川', '日野', '豊田', '八王子', '西八王子', '高尾', '新宿', '八幡山', '千歳烏山', '仙川', 'つつじヶ丘', '柴崎', '国領', '布田', '調布', '西調布', '飛田給', '武蔵野台', '多磨霊園', '東府中', '府中', '分倍河原', '中河原', '聖蹟桜ヶ丘', '百草園', '高幡不動', '南平', '平山城址公園', '長沼', '北野', '京王八王子']

# %%
print([station['station_name'] for _, station in stations_with_cluster.iterrows() if (station['cluster_number'] == 1)])
# Out:
# ['御茶ノ水', '中野', '高円寺', '阿佐ケ谷', '荻窪', '武蔵小金井', '笹塚', '代田橋', '明大前', '下高井戸', '桜上水', '上北沢', '芦花公園']
