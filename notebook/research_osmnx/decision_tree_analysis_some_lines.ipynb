# %%
import pandas as pd
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
stations = pd.read_csv('../../data/target_stations_with_stats.csv')

# %%
stations[stations['station_name_roman'] == 'kokubunji']
# Out:
#     Unnamed: 0  station_cd  station_g_cd station_name  station_name_k  \
# 15        1519     1131224       1131106          国分寺             NaN
#
#     station_name_r  line_cd  pref_cd      post           address  ...  \
# 15             NaN    11312       13  185-0012  東京都国分寺市本町二丁目1-23  ...
#
#     street_length_avg  street_segments_count node_density_km  \
# 15          62.358418                    804      237.330123
#
#    intersection_density_km  edge_density_km  street_density_km circuity_avg  \
# 15              214.767048     41748.082562       20948.631882     1.061068
#
#     self_loop_proportion  clean_intersection_count  \
# 15                   0.0                       338
#
#     clean_intersection_density_km
# 15                     141.228136
#
# [1 rows x 37 columns]

# %%
stations[['station_name', 'line_cd', 'address', 'lat', 'lon']]
# Out:
#    station_name  line_cd              address        lat         lon
# 0            東京    11312        東京都千代田区丸の内一丁目  35.681391  139.766103
# 1            神田    11312    東京都千代田区鍛冶町二丁目13-1  35.691173  139.770641
# 2          御茶ノ水    11312         千代田区神田駿河台２丁目  35.699605  139.764955
# 3           四ツ谷    11312          東京都新宿区四谷一丁目  35.686041  139.730644
# 4            新宿    11312      東京都新宿区新宿三丁目38-1  35.689729  139.700464
# 5            中野    11312             中野区中野５丁目  35.705765  139.665835
# 6           高円寺    11312           杉並区高円寺南４丁目  35.705326  139.649664
# 7          阿佐ケ谷    11312    東京都杉並区阿佐谷南三丁目36-3  35.704818  139.635868
# 8            荻窪    11312             杉並区上荻１丁目  35.704523  139.620109
# 9           西荻窪    11312            杉並区西荻南３丁目  35.703842  139.599361
# 10          吉祥寺    11312         東京都武蔵野市吉祥寺南町  35.703119  139.579765
# 11           三鷹    11312     東京都三鷹市下連雀三丁目46-1  35.702683  139.560325
# 12          武蔵境    11312             武蔵野市境１丁目  35.702083  139.543402
# 13         東小金井    11312           小金井市梶野町５丁目  35.701643  139.524837
# 14        武蔵小金井    11312            小金井市本町６丁目  35.701337  139.506483
# 15          国分寺    11312     東京都国分寺市本町二丁目1-23  35.700123  139.480841
# 16         西国分寺    11312          国分寺市西恋ケ窪２丁目  35.699744  139.465994
# 17           国立    11312              国立市北１丁目  35.699230  139.446340
# 18           立川    11312       東京都立川市曙町二丁目1-1  35.698202  139.413704
# 19           日野    11312            日野市大坂上１丁目  35.679244  139.393930
# 20           豊田    11312             日野市豊田４丁目  35.659502  139.381495
# 21          八王子    11312         東京都八王子市旭町1-1  35.655555  139.338998
# 22         西八王子    11312           八王子市千人町２丁目  35.656621  139.312640
# 23           高尾    11312              八王子市高尾町  35.642026  139.282288
# 24           新宿    24001      東京都新宿区西新宿一丁目1-4  35.690163  139.699187
# 25           笹塚    24001          渋谷区笹塚１-５６-７  35.673758  139.667251
# 26          代田橋    24001         世田谷区大原２-１８-９  35.671092  139.659413
# 27          明大前    24001         世田谷区松原２-４５-１  35.668758  139.650352
# 28         下高井戸    24001        世田谷区松原３-２９-１７  35.666150  139.641372
# 29          桜上水    24001       世田谷区桜上水５-２９-５２  35.667680  139.631290
# 30          上北沢    24001        世田谷区上北沢４-１４-３  35.668857  139.623290
# 31          八幡山    24001        杉並区上高井戸１-１-１１  35.669982  139.614927
# 32         芦花公園    24001        世田谷区南烏山３-１-１６  35.670479  139.608247
# 33         千歳烏山    24001         世田谷区南烏山６-１-１  35.667921  139.600670
# 34           仙川    24001           調布市仙川町１-４３  35.662257  139.584908
# 35        つつじヶ丘    24001  東京都調布市西つつじヶ丘三丁目35-1  35.657936  139.575103
# 36           柴崎    24001        調布市菊野台２-６７-１１  35.653997  139.566580
# 37           国領    24001         調布市国領町３-１８-１  35.650087  139.558036
# 38           布田    24001         調布市国領町５-６７-１  35.649904  139.551557
# 39           調布    24001          調布市布田４-３２-１  35.652181  139.543988
# 40          西調布    24001        調布市上石原１-２５-１７  35.657169  139.529822
# 41          飛田給    24001        調布市飛田給１-４２-１１  35.660121  139.523666
# 42         武蔵野台    24001         府中市白糸台４-１８-４  35.664159  139.511289
# 43         多磨霊園    24001       府中市清水が丘３-２６-１１  35.666197  139.502615
# 44          東府中    24001         府中市清水が丘１-８-３  35.668766  139.495257
# 45           府中    24001          府中市宮町１-１-１０  35.672245  139.479900
# 46         分倍河原    24001             府中市片町２丁目  35.668493  139.468798
# 47          中河原    24001         府中市住吉町２-１-１６  35.659549  139.457602
# 48        聖蹟桜ヶ丘    24001     東京都多摩市関戸一丁目10-10  35.650814  139.446979
# 49          百草園    24001             日野市百草２０９  35.657362  139.431285
# 50         高幡不動    24001             日野市高幡１３９  35.662361  139.412953
# 51           南平    24001          日野市南平６-９-３１  35.654559  139.392008
# 52       平山城址公園    24001         日野市平山５-１８-１０  35.647371  139.379926
# 53           長沼    24001           八王子市長沼町７００  35.642788  139.365849
# 54           北野    24001         八王子市打越町３３５-１  35.644479  139.354489
# 55        京王八王子    24001        八王子市明神町３-２７-１  35.657416  139.343851

# %%
X_columns = ['n', 'm', 'k_avg', 'intersection_count',
       'streets_per_node_avg', 'edge_length_total', 'edge_length_avg',
       'street_length_total', 'street_length_avg', 'street_segments_count',
       'node_density_km', 'intersection_density_km', 'edge_density_km',
       'street_density_km', 'circuity_avg', 'self_loop_proportion',
       'clean_intersection_count', 'clean_intersection_density_km']
y_columns = ['line_cd']

# %%
# !apt-get install -y graphviz
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fontconfig fontconfig-config fonts-dejavu-core fonts-liberation libcairo2
#   libcdt5 libcgraph6 libdatrie1 libfontconfig1 libfreetype6 libfribidi0 libgd3
#   libgraphite2-3 libgts-0.7-5 libgts-bin libgvc6 libgvpr2 libharfbuzz0b
#   libjbig0 libjpeg62-turbo liblab-gamut1 libltdl7 libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpathplan4 libpixman-1-0 libpng16-16
#   libthai-data libthai0 libtiff5 libwebp6 libxaw7 libxcb-render0 libxcb-shm0
#   libxdot4 libxmu6 libxpm4 libxt6
# Suggested packages:
#   gsfonts graphviz-doc libgd-tools
# The following NEW packages will be installed:
#   fontconfig fontconfig-config fonts-dejavu-core fonts-liberation graphviz
#   libcairo2 libcdt5 libcgraph6 libdatrie1 libfontconfig1 libfreetype6
#   libfribidi0 libgd3 libgraphite2-3 libgts-0.7-5 libgts-bin libgvc6 libgvpr2
#   libharfbuzz0b libjbig0 libjpeg62-turbo liblab-gamut1 libltdl7 libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpathplan4 libpixman-1-0 libpng16-16
#   libthai-data libthai0 libtiff5 libwebp6 libxaw7 libxcb-render0 libxcb-shm0
#   libxdot4 libxmu6 libxpm4 libxt6
# 0 upgraded, 40 newly installed, 0 to remove and 0 not upgraded.
# Need to get 10.8 MB of archives.
# After this operation, 27.3 MB of additional disk space will be used.
# Get:1 http://deb.debian.org/debian buster/main amd64 libpng16-16 amd64 1.6.36-6 [292 kB]
# Get:2 http://deb.debian.org/debian buster/main amd64 libfreetype6 amd64 2.9.1-3+deb10u1 [380 kB]
# Get:3 http://deb.debian.org/debian buster/main amd64 fonts-dejavu-core all 2.37-1 [1068 kB]
# Get:4 http://deb.debian.org/debian buster/main amd64 fonts-liberation all 1:1.07.4-9 [827 kB]
# Get:5 http://deb.debian.org/debian buster/main amd64 fontconfig-config all 2.13.1-2 [280 kB]
# Get:6 http://deb.debian.org/debian buster/main amd64 libfontconfig1 amd64 2.13.1-2 [346 kB]
# Get:7 http://deb.debian.org/debian buster/main amd64 fontconfig amd64 2.13.1-2 [405 kB]
# Get:8 http://deb.debian.org/debian buster/main amd64 libpixman-1-0 amd64 0.36.0-1 [537 kB]
# Get:9 http://deb.debian.org/debian buster/main amd64 libxcb-render0 amd64 1.13.1-2 [109 kB]
# Get:10 http://deb.debian.org/debian buster/main amd64 libxcb-shm0 amd64 1.13.1-2 [99.2 kB]
# Get:11 http://deb.debian.org/debian buster/main amd64 libcairo2 amd64 1.16.0-4 [689 kB]
# Get:12 http://deb.debian.org/debian buster/main amd64 libcdt5 amd64 2.40.1-6 [60.6 kB]
# Get:13 http://deb.debian.org/debian buster/main amd64 libcgraph6 amd64 2.40.1-6 [84.1 kB]
# Get:14 http://deb.debian.org/debian buster/main amd64 libjpeg62-turbo amd64 1:1.5.2-2+b1 [134 kB]
# Get:15 http://deb.debian.org/debian buster/main amd64 libjbig0 amd64 2.1-3.1+b2 [31.0 kB]
# Get:16 http://deb.debian.org/debian buster/main amd64 libwebp6 amd64 0.6.1-2 [263 kB]
# Get:17 http://deb.debian.org/debian buster/main amd64 libtiff5 amd64 4.1.0+git191117-2~deb10u1 [271 kB]
# Get:18 http://deb.debian.org/debian buster/main amd64 libxpm4 amd64 1:3.5.12-1 [49.1 kB]
# Get:19 http://deb.debian.org/debian buster/main amd64 libgd3 amd64 2.2.5-5.2 [136 kB]
# Get:20 http://deb.debian.org/debian buster/main amd64 libgts-0.7-5 amd64 0.7.6+darcs121130-4 [158 kB]
# Get:21 http://deb.debian.org/debian buster/main amd64 libltdl7 amd64 2.4.6-9 [390 kB]
# Get:22 http://deb.debian.org/debian buster/main amd64 libfribidi0 amd64 1.0.5-3.1+deb10u1 [63.7 kB]
# Get:23 http://deb.debian.org/debian buster/main amd64 libthai-data all 0.1.28-2 [170 kB]
# Get:24 http://deb.debian.org/debian buster/main amd64 libdatrie1 amd64 0.2.12-2 [39.3 kB]
# Get:25 http://deb.debian.org/debian buster/main amd64 libthai0 amd64 0.1.28-2 [54.1 kB]
# Get:26 http://deb.debian.org/debian buster/main amd64 libpango-1.0-0 amd64 1.42.4-7~deb10u1 [186 kB]
# Get:27 http://deb.debian.org/debian buster/main amd64 libgraphite2-3 amd64 1.3.13-7 [80.7 kB]
# Get:28 http://deb.debian.org/debian buster/main amd64 libharfbuzz0b amd64 2.3.1-1 [1187 kB]
# Get:29 http://deb.debian.org/debian buster/main amd64 libpangoft2-1.0-0 amd64 1.42.4-7~deb10u1 [67.9 kB]
# Get:30 http://deb.debian.org/debian buster/main amd64 libpangocairo-1.0-0 amd64 1.42.4-7~deb10u1 [55.5 kB]
# Get:31 http://deb.debian.org/debian buster/main amd64 libpathplan4 amd64 2.40.1-6 [63.5 kB]
# Get:32 http://deb.debian.org/debian buster/main amd64 libxdot4 amd64 2.40.1-6 [56.9 kB]
# Get:33 http://deb.debian.org/debian buster/main amd64 libgvc6 amd64 2.40.1-6 [646 kB]
# Get:34 http://deb.debian.org/debian buster/main amd64 libgvpr2 amd64 2.40.1-6 [213 kB]
# Get:35 http://deb.debian.org/debian buster/main amd64 liblab-gamut1 amd64 2.40.1-6 [220 kB]
# Get:36 http://deb.debian.org/debian buster/main amd64 libxt6 amd64 1:1.1.5-1+b3 [190 kB]
# Get:37 http://deb.debian.org/debian buster/main amd64 libxmu6 amd64 2:1.1.2-2+b3 [60.8 kB]
# Get:38 http://deb.debian.org/debian buster/main amd64 libxaw7 amd64 2:1.0.13-1+b2 [201 kB]
# Get:39 http://deb.debian.org/debian buster/main amd64 graphviz amd64 2.40.1-6 [594 kB]
# Get:40 http://deb.debian.org/debian buster/main amd64 libgts-bin amd64 0.7.6+darcs121130-4 [50.8 kB]
# Fetched 10.8 MB in 5s (2091 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
# Selecting previously unselected package libpng16-16:amd64.
# (Reading database ... 12564 files and directories currently installed.)
# Preparing to unpack .../00-libpng16-16_1.6.36-6_amd64.deb ...
# Unpacking libpng16-16:amd64 (1.6.36-6) ...
# Selecting previously unselected package libfreetype6:amd64.
# Preparing to unpack .../01-libfreetype6_2.9.1-3+deb10u1_amd64.deb ...
# Unpacking libfreetype6:amd64 (2.9.1-3+deb10u1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../02-fonts-dejavu-core_2.37-1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-1) ...
# Selecting previously unselected package fonts-liberation.
# Preparing to unpack .../03-fonts-liberation_1%3a1.07.4-9_all.deb ...
# Unpacking fonts-liberation (1:1.07.4-9) ...
# Selecting previously unselected package fontconfig-config.
# Preparing to unpack .../04-fontconfig-config_2.13.1-2_all.deb ...
# Unpacking fontconfig-config (2.13.1-2) ...
# Selecting previously unselected package libfontconfig1:amd64.
# Preparing to unpack .../05-libfontconfig1_2.13.1-2_amd64.deb ...
# Unpacking libfontconfig1:amd64 (2.13.1-2) ...
# Selecting previously unselected package fontconfig.
# Preparing to unpack .../06-fontconfig_2.13.1-2_amd64.deb ...
# Unpacking fontconfig (2.13.1-2) ...
# Selecting previously unselected package libpixman-1-0:amd64.
# Preparing to unpack .../07-libpixman-1-0_0.36.0-1_amd64.deb ...
# Unpacking libpixman-1-0:amd64 (0.36.0-1) ...
# Selecting previously unselected package libxcb-render0:amd64.
# Preparing to unpack .../08-libxcb-render0_1.13.1-2_amd64.deb ...
# Unpacking libxcb-render0:amd64 (1.13.1-2) ...
# Selecting previously unselected package libxcb-shm0:amd64.
# Preparing to unpack .../09-libxcb-shm0_1.13.1-2_amd64.deb ...
# Unpacking libxcb-shm0:amd64 (1.13.1-2) ...
# Selecting previously unselected package libcairo2:amd64.
# Preparing to unpack .../10-libcairo2_1.16.0-4_amd64.deb ...
# Unpacking libcairo2:amd64 (1.16.0-4) ...
# Selecting previously unselected package libcdt5.
# Preparing to unpack .../11-libcdt5_2.40.1-6_amd64.deb ...
# Unpacking libcdt5 (2.40.1-6) ...
# Selecting previously unselected package libcgraph6.
# Preparing to unpack .../12-libcgraph6_2.40.1-6_amd64.deb ...
# Unpacking libcgraph6 (2.40.1-6) ...
# Selecting previously unselected package libjpeg62-turbo:amd64.
# Preparing to unpack .../13-libjpeg62-turbo_1%3a1.5.2-2+b1_amd64.deb ...
# Unpacking libjpeg62-turbo:amd64 (1:1.5.2-2+b1) ...
# Selecting previously unselected package libjbig0:amd64.
# Preparing to unpack .../14-libjbig0_2.1-3.1+b2_amd64.deb ...
# Unpacking libjbig0:amd64 (2.1-3.1+b2) ...
# Selecting previously unselected package libwebp6:amd64.
# Preparing to unpack .../15-libwebp6_0.6.1-2_amd64.deb ...
# Unpacking libwebp6:amd64 (0.6.1-2) ...
# Selecting previously unselected package libtiff5:amd64.
# Preparing to unpack .../16-libtiff5_4.1.0+git191117-2~deb10u1_amd64.deb ...
# Unpacking libtiff5:amd64 (4.1.0+git191117-2~deb10u1) ...
# Selecting previously unselected package libxpm4:amd64.
# Preparing to unpack .../17-libxpm4_1%3a3.5.12-1_amd64.deb ...
# Unpacking libxpm4:amd64 (1:3.5.12-1) ...
# Selecting previously unselected package libgd3:amd64.
# Preparing to unpack .../18-libgd3_2.2.5-5.2_amd64.deb ...
# Unpacking libgd3:amd64 (2.2.5-5.2) ...
# Selecting previously unselected package libgts-0.7-5:amd64.
# Preparing to unpack .../19-libgts-0.7-5_0.7.6+darcs121130-4_amd64.deb ...
# Unpacking libgts-0.7-5:amd64 (0.7.6+darcs121130-4) ...
# Selecting previously unselected package libltdl7:amd64.
# Preparing to unpack .../20-libltdl7_2.4.6-9_amd64.deb ...
# Unpacking libltdl7:amd64 (2.4.6-9) ...
# Selecting previously unselected package libfribidi0:amd64.
# Preparing to unpack .../21-libfribidi0_1.0.5-3.1+deb10u1_amd64.deb ...
# Unpacking libfribidi0:amd64 (1.0.5-3.1+deb10u1) ...
# Selecting previously unselected package libthai-data.
# Preparing to unpack .../22-libthai-data_0.1.28-2_all.deb ...
# Unpacking libthai-data (0.1.28-2) ...
# Selecting previously unselected package libdatrie1:amd64.
# Preparing to unpack .../23-libdatrie1_0.2.12-2_amd64.deb ...
# Unpacking libdatrie1:amd64 (0.2.12-2) ...
# Selecting previously unselected package libthai0:amd64.
# Preparing to unpack .../24-libthai0_0.1.28-2_amd64.deb ...
# Unpacking libthai0:amd64 (0.1.28-2) ...
# Selecting previously unselected package libpango-1.0-0:amd64.
# Preparing to unpack .../25-libpango-1.0-0_1.42.4-7~deb10u1_amd64.deb ...
# Unpacking libpango-1.0-0:amd64 (1.42.4-7~deb10u1) ...
# Selecting previously unselected package libgraphite2-3:amd64.
# Preparing to unpack .../26-libgraphite2-3_1.3.13-7_amd64.deb ...
# Unpacking libgraphite2-3:amd64 (1.3.13-7) ...
# Selecting previously unselected package libharfbuzz0b:amd64.
# Preparing to unpack .../27-libharfbuzz0b_2.3.1-1_amd64.deb ...
# Unpacking libharfbuzz0b:amd64 (2.3.1-1) ...
# Selecting previously unselected package libpangoft2-1.0-0:amd64.
# Preparing to unpack .../28-libpangoft2-1.0-0_1.42.4-7~deb10u1_amd64.deb ...
# Unpacking libpangoft2-1.0-0:amd64 (1.42.4-7~deb10u1) ...
# Selecting previously unselected package libpangocairo-1.0-0:amd64.
# Preparing to unpack .../29-libpangocairo-1.0-0_1.42.4-7~deb10u1_amd64.deb ...
# Unpacking libpangocairo-1.0-0:amd64 (1.42.4-7~deb10u1) ...
# Selecting previously unselected package libpathplan4.
# Preparing to unpack .../30-libpathplan4_2.40.1-6_amd64.deb ...
# Unpacking libpathplan4 (2.40.1-6) ...
# Selecting previously unselected package libxdot4.
# Preparing to unpack .../31-libxdot4_2.40.1-6_amd64.deb ...
# Unpacking libxdot4 (2.40.1-6) ...
# Selecting previously unselected package libgvc6.
# Preparing to unpack .../32-libgvc6_2.40.1-6_amd64.deb ...
# Unpacking libgvc6 (2.40.1-6) ...
# Selecting previously unselected package libgvpr2.
# Preparing to unpack .../33-libgvpr2_2.40.1-6_amd64.deb ...
# Unpacking libgvpr2 (2.40.1-6) ...
# Selecting previously unselected package liblab-gamut1.
# Preparing to unpack .../34-liblab-gamut1_2.40.1-6_amd64.deb ...
# Unpacking liblab-gamut1 (2.40.1-6) ...
# Selecting previously unselected package libxt6:amd64.
# Preparing to unpack .../35-libxt6_1%3a1.1.5-1+b3_amd64.deb ...
# Unpacking libxt6:amd64 (1:1.1.5-1+b3) ...
# Selecting previously unselected package libxmu6:amd64.
# Preparing to unpack .../36-libxmu6_2%3a1.1.2-2+b3_amd64.deb ...
# Unpacking libxmu6:amd64 (2:1.1.2-2+b3) ...
# Selecting previously unselected package libxaw7:amd64.
# Preparing to unpack .../37-libxaw7_2%3a1.0.13-1+b2_amd64.deb ...
# Unpacking libxaw7:amd64 (2:1.0.13-1+b2) ...
# Selecting previously unselected package graphviz.
# Preparing to unpack .../38-graphviz_2.40.1-6_amd64.deb ...
# Unpacking graphviz (2.40.1-6) ...
# Selecting previously unselected package libgts-bin.
# Preparing to unpack .../39-libgts-bin_0.7.6+darcs121130-4_amd64.deb ...
# Unpacking libgts-bin (0.7.6+darcs121130-4) ...
# Setting up libxdot4 (2.40.1-6) ...
# Setting up libgraphite2-3:amd64 (1.3.13-7) ...
# Setting up libpixman-1-0:amd64 (0.36.0-1) ...
# Setting up libxpm4:amd64 (1:3.5.12-1) ...
# Setting up libdatrie1:amd64 (0.2.12-2) ...
# Setting up libxcb-render0:amd64 (1.13.1-2) ...
# Setting up liblab-gamut1 (2.40.1-6) ...
# Setting up libxcb-shm0:amd64 (1.13.1-2) ...
# Setting up libjbig0:amd64 (2.1-3.1+b2) ...
# Setting up libgts-0.7-5:amd64 (0.7.6+darcs121130-4) ...
# Setting up libjpeg62-turbo:amd64 (1:1.5.2-2+b1) ...
# Setting up libpathplan4 (2.40.1-6) ...
# Setting up libfribidi0:amd64 (1.0.5-3.1+deb10u1) ...
# Setting up libpng16-16:amd64 (1.6.36-6) ...
# Setting up libwebp6:amd64 (0.6.1-2) ...
# Setting up fonts-dejavu-core (2.37-1) ...
# Setting up libxt6:amd64 (1:1.1.5-1+b3) ...
# Setting up libltdl7:amd64 (2.4.6-9) ...
# Setting up fonts-liberation (1:1.07.4-9) ...
# Setting up libthai-data (0.1.28-2) ...
# Setting up libcdt5 (2.40.1-6) ...
# Setting up libcgraph6 (2.40.1-6) ...
# Setting up libtiff5:amd64 (4.1.0+git191117-2~deb10u1) ...
# Setting up libgts-bin (0.7.6+darcs121130-4) ...
# Setting up libxmu6:amd64 (2:1.1.2-2+b3) ...
# Setting up fontconfig-config (2.13.1-2) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Setting up libxaw7:amd64 (2:1.0.13-1+b2) ...
# Setting up libthai0:amd64 (0.1.28-2) ...
# Setting up libfreetype6:amd64 (2.9.1-3+deb10u1) ...
# Setting up libgvpr2 (2.40.1-6) ...
# Setting up libharfbuzz0b:amd64 (2.3.1-1) ...
# Setting up libfontconfig1:amd64 (2.13.1-2) ...
# Setting up fontconfig (2.13.1-2) ...
# Regenerating fonts cache... done.
# Setting up libpango-1.0-0:amd64 (1.42.4-7~deb10u1) ...
# Setting up libcairo2:amd64 (1.16.0-4) ...
# Setting up libgd3:amd64 (2.2.5-5.2) ...
# Setting up libpangoft2-1.0-0:amd64 (1.42.4-7~deb10u1) ...
# Setting up libpangocairo-1.0-0:amd64 (1.42.4-7~deb10u1) ...
# Setting up libgvc6 (2.40.1-6) ...
# Setting up graphviz (2.40.1-6) ...
# Processing triggers for libc-bin (2.28-10) ...

# %%
# !pip install pydotplus
# !pip install graphviz
# Out:
# Requirement already satisfied: pydotplus in /opt/conda/lib/python3.8/site-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in /opt/conda/lib/python3.8/site-packages (from pydotplus) (2.4.7)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.8/site-packages (0.14.1)

# %%
from sklearn.tree import  DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# データ分割
X = stations[X_columns]
y = stations[y_columns]
X_train = X
y_train = y
#X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# 決定木クラスの初期化と学習
model = DecisionTreeClassifier(criterion='entropy', max_depth=5, random_state=0)
model.fit(X_train, y_train)

print('正解率(train):{:.3f}'.format(model.score(X_train, y_train)))
#print('正解率(test):{:.3f}'.format(model.score(X_test, y_test)))
# Out:
# 正解率(train):0.964

# %%
# 参考プログラム
# pydotplusやgraphvizをインストールする必要があります
from sklearn import tree
import pydotplus
from sklearn.externals.six import StringIO
from IPython.display import Image

dot_data = StringIO()
tree.export_graphviz(model, out_file=dot_data)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
print(X_columns[14])
print(X_columns[4])

print(X_columns[5])
print(X_columns[8])
print(X_columns[17])
print(X_columns[2])
# Out:
# circuity_avg
# streets_per_node_avg
# edge_length_total
# street_length_avg
# clean_intersection_density_km
# k_avg

# %%
# 路線ごとの回路の平均数、交差点あたりの通り数の平均のグラフ化
ax = None
colors = {11312: 'red', 24001: 'pink'}
for i, station in stations.groupby('line_cd'):
    station.plot.scatter(x='circuity_avg', y='streets_per_node_avg', color=colors[i], label='cluster{i}', ax=ax)

# %%
# k-means法を使うためのインポート
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# データの列の絞り込み
stations_sub = stations[['circuity_avg','streets_per_node_avg']]

# 標準化
sc = StandardScaler()
sc.fit(stations_sub)
stations_sub_std = sc.transform(stations_sub)

# %%
# KMeansクラスの初期化
kmeans = KMeans(init='random', n_clusters=2, random_state=0)

# クラスターの重心を計算
kmeans.fit(stations_sub_std)

# クラスター番号をpandasのSeriesオブジェクトに変換
labels = pd.Series(kmeans.labels_, name='cluster_number', index=stations.index)

# クラスター番号と件数を表示
print(labels.value_counts(sort=False))

# グラフを描画
ax = labels.value_counts(sort=False).plot(kind='bar')
ax.set_xlabel('cluster number')
ax.set_ylabel('count')
# Out:
# 0    15
# 1    41
# Name: cluster_number, dtype: int64
# Text(0, 0.5, 'count')

# %%
# 駅のデータにクラスター番号のデータを結合
stations_with_cluster = pd.concat([stations, pd.Series(labels, index=stations.index)], axis=1)

# 先頭の5行を表示
stations_with_cluster.head()
# Out:
#    Unnamed: 0  station_cd  station_g_cd station_name  station_name_k  \
# 0        1504     1131201       1130101           東京             NaN
# 1        1505     1131202       1130223           神田             NaN
# 2        1506     1131203       1131203         御茶ノ水             NaN
# 3        1507     1131207       1131102          四ツ谷             NaN
# 4        1508     1131211       1130208           新宿             NaN
#
#    station_name_r  line_cd  pref_cd      post            address  ...  \
# 0             NaN    11312       13  100-0005      東京都千代田区丸の内一丁目  ...
# 1             NaN    11312       13  101-0044  東京都千代田区鍛冶町二丁目13-1  ...
# 2             NaN    11312       13  101-0062       千代田区神田駿河台２丁目  ...
# 3             NaN    11312       13  160-0004        東京都新宿区四谷一丁目  ...
# 4             NaN    11312       13  160-0022    東京都新宿区新宿三丁目38-1  ...
#
#    street_segments_count  node_density_km intersection_density_km  \
# 0                    687       189.776780              187.564929
# 1                   1566       401.974424              396.166744
# 2                   1737       439.250321              427.732907
# 3                    663       202.387111              169.478638
# 4                   1081       291.609617              278.503567
#
#   edge_density_km  street_density_km  circuity_avg self_loop_proportion  \
# 0    26579.884081       22730.444358      1.013870             0.001239
# 1    43475.857491       35573.377567      1.010249             0.000515
# 2    44209.465308       32228.566100      1.007648             0.000000
# 3    28917.003433       18097.028930      1.041710             0.000000
# 4    36083.913658       24834.827357      1.023062             0.000000
#
#    clean_intersection_count  clean_intersection_density_km  cluster_number
# 0                       241                     106.611198               0
# 1                       511                     211.980321               0
# 2                       543                     215.653638               0
# 3                       255                     104.895759               1
# 4                       397                     162.596935               0
#
# [5 rows x 38 columns]

# %%
stations_0 = stations_with_cluster[stations_with_cluster['cluster_number'] == 0]
stations_1 = stations_with_cluster[stations_with_cluster['cluster_number'] == 1]
# クラスタリング結果のグラフ化
ax = None
colors = ['red', 'pink']
for i, station in stations_with_cluster.groupby('cluster_number'):
    station.plot.scatter(x='circuity_avg', y='streets_per_node_avg', color=colors[i], label='cluster{i}', ax=ax)

# %%
# クラスタ番号と年齢層を軸に集計し、年齢層を列に設定
cross_cluster_line_cd = stations_with_cluster.groupby(['cluster_number', 'line_cd']).size().unstack().fillna(0)
cross_cluster_line_cd
# Out:
# line_cd         11312  24001
# cluster_number
# 0                  12      3
# 1                  12     29

# %%
sns.heatmap(cross_cluster_line_cd.apply(lambda x : x/x.sum(), axis=1), cmap='Blues')

# %%
print([station['station_name'] for _, station in stations_with_cluster.iterrows() if (station['cluster_number'] == 0)])
# Out:
# ['東京', '神田', '御茶ノ水', '新宿', '高円寺', '西荻窪', '吉祥寺', '三鷹', '立川', '豊田', '八王子', '西八王子', '新宿', '府中', '京王八王子']

# %%
print([station['station_name'] for _, station in stations_with_cluster.iterrows() if (station['cluster_number'] == 1)])
# Out:
# ['四ツ谷', '中野', '阿佐ケ谷', '荻窪', '武蔵境', '東小金井', '武蔵小金井', '国分寺', '西国分寺', '国立', '日野', '高尾', '笹塚', '代田橋', '明大前', '下高井戸', '桜上水', '上北沢', '八幡山', '芦花公園', '千歳烏山', '仙川', 'つつじヶ丘', '柴崎', '国領', '布田', '調布', '西調布', '飛田給', '武蔵野台', '多磨霊園', '東府中', '分倍河原', '中河原', '聖蹟桜ヶ丘', '百草園', '高幡不動', '南平', '平山城址公園', '長沼', '北野']
