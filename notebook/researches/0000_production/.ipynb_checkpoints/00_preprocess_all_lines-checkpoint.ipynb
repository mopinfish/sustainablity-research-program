# %%
import networkx as nx
import osmnx as ox
import requests
import sys,os,os.path
import pandas as pd
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

ox.config(use_cache=True, log_console=True)
ox.__version__
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/conda/share/proj failed
# /opt/conda/lib/python3.10/site-packages/osmnx/utils.py:192: UserWarning: The `utils.config` function is deprecated and will be removed in a future release. Instead, use the `settings` module directly to configure a global setting's value. For example, `ox.settings.log_console=True`.
#   warnings.warn(
# '1.2.1'

# %%
stations = pd.read_csv('../../../data/stations.csv')

# %%
stations.head()
# Out:
#    station_cd  station_g_cd station_name  station_name_k  station_name_r  \
# 0     1110101       1110101           函館             NaN             NaN
# 1     1110102       1110102          五稜郭             NaN             NaN
# 2     1110103       1110103           桔梗             NaN             NaN
# 3     1110104       1110104          大中山             NaN             NaN
# 4     1110105       1110105           七飯             NaN             NaN
#
#    line_cd  pref_cd      post           address         lon        lat  \
# 0    11101        1  040-0063    北海道函館市若松町１２-１３  140.726413  41.773709
# 1    11101        1  041-0813           函館市亀田本町  140.733539  41.803557
# 2    11101        1  041-0801  北海道函館市桔梗３丁目４１-３６  140.722952  41.846457
# 3    11101        1  041-1121       亀田郡七飯町大字大中山  140.713580  41.864641
# 4    11101        1  041-1111         亀田郡七飯町字本町  140.688556  41.886971
#
#      open_ymd   close_ymd  e_status   e_sort station_name_roman
# 0  1902-12-10  0000-00-00         0  1110101           hakodate
# 1  0000-00-00  0000-00-00         0  1110102         goryoukaku
# 2  1902-12-10  0000-00-00         0  1110103             kikyou
# 3  0000-00-00  0000-00-00         0  1110104        daichuuyama
# 4  0000-00-00  0000-00-00         0  1110105              nanae

# %%
#!sudo apt upgrade -y
#!sudo apt update -y
# !sudo apt-get install -y git
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package git

# %%
# 日本語・ローマ字変換ライブラリ `pykakasi` をインストール
# !pip install pykakasi
# Out:
# Requirement already satisfied: pykakasi in /opt/conda/lib/python3.10/site-packages (2.2.1)
# Requirement already satisfied: deprecated in /opt/conda/lib/python3.10/site-packages (from pykakasi) (1.2.13)
# Requirement already satisfied: jaconv in /opt/conda/lib/python3.10/site-packages (from pykakasi) (0.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/lib/python3.10/site-packages (from deprecated->pykakasi) (1.14.1)

# %%
from pykakasi import kakasi

kakasi = kakasi()

kakasi.setMode('H', 'a')
kakasi.setMode('K', 'a')
kakasi.setMode('J', 'a')

conv = kakasi.getConverter()
# Out:
# /tmp/ipykernel_63/2555217817.py:5: DeprecationWarning: Call to deprecated method setMode. (Old API will be removed in v3.0.) -- Deprecated since version 2.1.
#   kakasi.setMode('H', 'a')
# /tmp/ipykernel_63/2555217817.py:6: DeprecationWarning: Call to deprecated method setMode. (Old API will be removed in v3.0.) -- Deprecated since version 2.1.
#   kakasi.setMode('K', 'a')
# /tmp/ipykernel_63/2555217817.py:7: DeprecationWarning: Call to deprecated method setMode. (Old API will be removed in v3.0.) -- Deprecated since version 2.1.
#   kakasi.setMode('J', 'a')
# /tmp/ipykernel_63/2555217817.py:9: DeprecationWarning: Call to deprecated method getConverter. (Old API will be removed in v3.0.) -- Deprecated since version 2.1.
#   conv = kakasi.getConverter()

# %%
# 駅名のローマ字名を付与
stations['station_name_roman'] = stations['station_name'].apply(lambda name: conv.do(name))
stations
# Out:
# /tmp/ipykernel_63/243963799.py:2: DeprecationWarning: Call to deprecated method do. (Old API will be removed in v3.0.) -- Deprecated since version 2.1.
#   stations['station_name_roman'] = stations['station_name'].apply(lambda name: conv.do(name))
#        station_cd  station_g_cd station_name  station_name_k  station_name_r  \
# 0         1110101       1110101           函館             NaN             NaN
# 1         1110102       1110102          五稜郭             NaN             NaN
# 2         1110103       1110103           桔梗             NaN             NaN
# 3         1110104       1110104          大中山             NaN             NaN
# 4         1110105       1110105           七飯             NaN             NaN
# ...           ...           ...          ...             ...             ...
# 10850     9992719       9992719        てだこ浦西             NaN             NaN
# 10851     9992801       1190202      九州鉄道記念館             NaN             NaN
# 10852     9992802       9992802        出光美術館             NaN             NaN
# 10853     9992803       9992803     ノーフォーク広場             NaN             NaN
# 10854     9992804       9992804      関門海峡めかり             NaN             NaN
#
#        line_cd  pref_cd      post           address         lon        lat  \
# 0        11101        1  040-0063    北海道函館市若松町１２-１３  140.726413  41.773709
# 1        11101        1  041-0813           函館市亀田本町  140.733539  41.803557
# 2        11101        1  041-0801  北海道函館市桔梗３丁目４１-３６  140.722952  41.846457
# 3        11101        1  041-1121       亀田郡七飯町大字大中山  140.713580  41.864641
# 4        11101        1  041-1111         亀田郡七飯町字本町  140.688556  41.886971
# ...        ...      ...       ...               ...         ...        ...
# 10850    99927       47  901-2102     沖縄県浦添市前田三丁目21  127.741861  26.241778
# 10851    99928       40  800-0000        福岡県北九州市門司区  130.962439  33.944392
# 10852    99928       40  800-0000        福岡県北九州市門司区  130.965292  33.947792
# 10853    99928       40  801-0854     福岡県北九州市門司区旧門司  130.964254  33.955973
# 10854    99928       40  801-0855      福岡県北九州市門司区門司  130.967347  33.960627
#
#          open_ymd   close_ymd  e_status   e_sort        station_name_roman
# 0      1902-12-10  0000-00-00         0  1110101                  hakodate
# 1      0000-00-00  0000-00-00         0  1110102                goryoukaku
# 2      1902-12-10  0000-00-00         0  1110103                    kikyou
# 3      0000-00-00  0000-00-00         0  1110104               daichuuyama
# 4      0000-00-00  0000-00-00         0  1110105                     nanae
# ...           ...         ...       ...      ...                       ...
# 10850  2019-10-01  0000-00-00         0  9992719            tedakouranishi
# 10851  0000-00-00  0000-00-00         0  9992801  kyuushuutetsudoukinenkan
# 10852  0000-00-00  0000-00-00         0  9992802        idemitsubijutsukan
# 10853  0000-00-00  0000-00-00         0  9992803            noofookuhiroba
# 10854  0000-00-00  0000-00-00         0  9992804       kanmonkaikyoumekari
#
# [10855 rows x 16 columns]

# %%
# stations.to_csv('../../../data/stations.csv', index=False)

# %%
target_stations = stations[stations['pref_cd'].isin([11, 12, 13, 14])]
len(target_stations)
# Out:
# 2032

# %%
import folium

# %%
center_lat, center_lon = (35.651820534474, 139.54461236426)

_map = folium.Map(location=[center_lat, center_lon], zoom_start=12)

colors = {
    11312: 'red',
    25001: 'blue',
    24001: 'pink',
    27001: 'gray',
}


for _, station in target_stations.iterrows():
    color = 'red'
    folium.Marker([station.lat, station.lon], popup=str(station['station_name']), icon=folium.Icon(color=color)).add_to(_map)

_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eebecffa1716d9fe0e77f27f570ae3b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eebecffa1716d9fe0e77f27f570ae3b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_eebecffa1716d9fe0e77f27f570ae3b3 = L.map(
#                 &quot;map_eebecffa1716d9fe0e77f27f570ae3b3&quot;,
#                 {
#                     center: [35.651820534474, 139.54461236426],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e3afb231709d7339a27f305f6fbf355f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_eebecffa1716d9fe0e77f27f570ae3b3);
#
#
#             var marker_78c36e435350b6d05f49f40e21bda42f = L.marker(
#                 [35.681391, 139.766103],
#                 {}
#             ).addTo(map_eebecffa1716d9fe0e77f27f570ae3b3);
#
#
#             var icon_bc766b5551a6bd6da00bc28cbba02577 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_78c36e435350b6d05f49f40e21bda42f.setIcon(icon_bc766b5551a6bd6da00bc28cbba02577);
#
#
#         var popup_c6442424a8e5df047a3c46faaf47ca98 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0c48955899841641fa8049b176f03974 = $(`&lt;div id=&quot;html_0c48955899841641fa8049b176f03974&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;東京&lt;/div&gt;`)[0];
#             popup_c6442424a8e5df047a3c46faaf47ca98.setContent(html_0c48955899841641fa8049b176f03974);
#
#
#         marker_78c36e435350b6d05f49f40e21bda42f.bindPopup(popup_c6442424a8e5df047a3c46faaf47ca98)
#         ;
#
#
#
#
#             var marker_f1b28a72edebb379062c6026f849ad0f = L.marker(
#                 [35.666195, 139.758587],
#                 {}
#             ).addTo(map_eebecffa1716d9fe0e77f27f570ae3b3);
#
#
#             var icon_29dc3c3149106b7f0c41b27993c35f5c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f1b28a72edebb379062c6026f849ad0f.setIcon(icon_29dc3c3149106b7f0c41b27993c35f5c);
#
#
#         var popup_649a5a8e551f06aa44b91a4598e670b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_387b797a84cce0016770002c27e000d7 = $(`&lt;div id=&quot;html_387b797a84cce0016770002c27e000d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;新橋&lt;/div&gt;`)[0];
#             popup_649a5a8e551f06aa44b91a4598e670b8.setContent(html_387b797a84cce0016770002c27e000d7);
#
#
#         marker_f1b28a72edebb379062c6026f849ad0f.bindPopup(popup_649a5a8e551f06aa44b91a4598e670b8)
#         ;
#
#
#
#
#             var marker_cd983eb7fb73483ecdc991d9a5e4952e = L.marker(
#                 [35.62876, 139.738999],
#                 {}
#             ).addTo(map_eebecffa1716d9fe0e77f27f570ae3b3);
#
#
#             var icon_1214a61e504581b317d31bfdc079dbf8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cd983eb7fb73483ecdc991d9a5e4952e.setIcon(icon_1214a61e504581b317d31bfdc079dbf8);
#
#
#         var popup_74925859e859b355e588bc17ed30b36f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d06cd1bf13e0c455015039f42b838f0d = $(`&lt;div id=&quot;html_d06cd1bf13e0c455015039f42b838f0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;品川&lt;/div&gt;`)[0];
#             popup_74925859e859b355e588bc17ed30b36f.setContent(html_d06cd1bf13e0c455015039f42b838f0d);
#
#
#         marker_cd983eb7fb73483ecdc991d9a5e4952e.bindPopup(popup_74925859e859b355e588bc17ed30b36f)
#         ;
#
#
#
#
#             var marker_cec632967e4c86bc0a3dda1fe9178cdf = L.marker(
#                 [35.531311, 139.697485],
#                 {}
#             ).addTo(map_eebecffa1716d9fe0e77f27f570ae3b3);
#
#
#             var icon_763949d88653a204ed808ac8a5225ec3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cec632967e4c86bc0a3dda1fe9178cdf.setIcon(icon_763949d88653a204ed808ac8a5225ec3);

# %%
## cluster coefficient from osmnx graph

# density ------------------------------------------------------------------------------------
def calc_density(G):
    key = 'density'
    density_val = round(nx.density(G),8)

    return density_val

# cluster coefficient-------------------------------------------------------------------------
def calc_cluster_coefficient(G):
    key = 'cluster_coefficient'
    G2 = nx.Graph(G)
    cluster_coefficient = nx.clustering(G2, weight='length')

    return cluster_coefficient

# MultiDiGraphでは計算できないのでDiGraphに変換
# MultiDiGraph edge num: 10515
# DiGraph      edge num: 10441 
# average cluster coefficient-----------------------------------------------------------------
def calc_avg_cluster_coefficient(G):
    key = 'average_cluster_coefficient'

    G2 = nx.DiGraph(G)

    # G2_edges = set(G2.edges())
    # for edge in set(G.edges()):
    #     if edge not in G2_edges:
    #         print(edge)

    avg_cluster_coefficient = round(nx.average_clustering(G2, weight='length'), 7)

    return avg_cluster_coefficient

# %%
import time
#駅の800m範囲内のグラフ構造の配列を取得
def get_stats(data):
    wurster_hall = (data['lat'], data['lon'])
    one_mile = 800 #meters


    try:
        G = ox.graph_from_point(wurster_hall, dist=one_mile, network_type='drive')
        if G is None:
            return pd.Series([])

        # what sized area does our network cover in square meters?
        G_proj = ox.project_graph(G)
        nodes_proj = ox.graph_to_gdfs(G_proj, edges=False)
        graph_area_m = nodes_proj.unary_union.convex_hull.area

        if graph_area_m == 0:
            print(data)
            print(graph_area_m)
            print(nodes_proj)
            print(G_proj)
            return pd.Series([])

        # show some basic stats about the network
        stats = ox.basic_stats(G_proj, area=graph_area_m)
        
        # calculate cluster coefficient
        stats['density'] = calc_density(G)
        stats['avg_cluster_coefficient'] = calc_avg_cluster_coefficient(G)

        time.sleep(0.5)
        return pd.Series(stats)

    except ConnectionError as e:
        print(data)
        print(e)
        return pd.Series([])
    
#    except nx.NetworkXPointlessConcept as e:

# %%
# 欠損している駅（海芝浦）を除く
target_stations = target_stations[target_stations['station_cd'] != 1130407]
len(target_stations)
# Out:
# 2031

# %%
# %%time

# 統計情報取得のテスト
stats_list = target_stations[:1].apply(get_stats, axis=1)
stats_list
# Out:
# CPU times: user 1.12 s, sys: 13.1 ms, total: 1.13 s
# Wall time: 1.63 s
#         n    m     k_avg  edge_length_total  edge_length_avg  \
# 1262  422  791  3.748815          57917.271        73.220317
#
#       streets_per_node_avg                          streets_per_node_counts  \
# 1262              3.419431  {0: 0, 1: 8, 2: 6, 3: 225, 4: 170, 5: 10, 6: 3}
#
#                            streets_per_node_proportions  intersection_count  \
# 1262  {0: 0.0, 1: 0.018957345971563982, 2: 0.0142180...                 414
#
#       street_length_total  street_segment_count  street_length_avg  \
# 1262             49689.96                   671          74.053592
#
#       circuity_avg  self_loop_proportion  node_density_km  \
# 1262      1.013863               0.00149       186.383769
#
#       intersection_density_km  edge_density_km  street_density_km   density  \
# 1262               182.850427     25580.187829       21946.450309  0.004452
#
#       avg_cluster_coefficient
# 1262                 0.001608

# %%
# %%time

#駅の800m範囲内のグラフ構造の配列を取得
stats_list = target_stations.apply(get_stats, axis=1)
stats_list
# Out:
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/urllib3/response.py:441, in HTTPResponse._error_catcher(self)
#     440 try:
# --> 441     yield
#     443 except SocketTimeout:
#     444     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     445     # there is yet no clean way to get at it from this context.
#
# File /opt/conda/lib/python3.10/site-packages/urllib3/response.py:770, in HTTPResponse.read_chunked(self, amt, decode_content)
#     769     break
# --> 770 chunk = self._handle_chunk(amt)
#     771 decoded = self._decode(
#     772     chunk, decode_content=decode_content, flush_decoder=False
#     773 )
#
# File /opt/conda/lib/python3.10/site-packages/urllib3/response.py:723, in HTTPResponse._handle_chunk(self, amt)
#     722 else:  # amt > self.chunk_left
# --> 723     returned_chunk = self._fp._safe_read(self.chunk_left)
#     724     self._fp._safe_read(2)  # Toss the CRLF at the end of the chunk.
#
# File /opt/conda/lib/python3.10/http/client.py:632, in HTTPResponse._safe_read(self, amt)
#     631 if len(data) < amt:
# --> 632     raise IncompleteRead(data, amt-len(data))
#     633 return data
#
# IncompleteRead: IncompleteRead(0 bytes read, 8096 more expected)
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     815 try:
# --> 816     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     817         yield chunk
#
# File /opt/conda/lib/python3.10/site-packages/urllib3/response.py:575, in HTTPResponse.stream(self, amt, decode_content)
#     574 if self.chunked and self.supports_chunked_reads():
# --> 575     for line in self.read_chunked(amt, decode_content=decode_content):
#     576         yield line
#
# File /opt/conda/lib/python3.10/site-packages/urllib3/response.py:755, in HTTPResponse.read_chunked(self, amt, decode_content)
#     750     raise BodyNotHttplibCompatible(
#     751         "Body should be http.client.HTTPResponse like. "
#     752         "It should have have an fp attribute which returns raw chunks."
#     753     )
# --> 755 with self._error_catcher():
#     756     # Don't bother reading the body of a HEAD request.
#     757     if self._original_response and is_response_to_head(self._original_response):
#
# File /opt/conda/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File /opt/conda/lib/python3.10/site-packages/urllib3/response.py:458, in HTTPResponse._error_catcher(self)
#     456 except (HTTPException, SocketError) as e:
#     457     # This includes IncompleteRead.
# --> 458     raise ProtocolError("Connection broken: %r" % e, e)
#     460 # If no exception is thrown, we should avoid cleaning up
#     461 # unnecessarily.
#
# ProtocolError: ('Connection broken: IncompleteRead(0 bytes read, 8096 more expected)', IncompleteRead(0 bytes read, 8096 more expected))
#
# During handling of the above exception, another exception occurred:
#
# ChunkedEncodingError                      Traceback (most recent call last)
# Input In [30], in get_stats(data)
#       8 try:
# ----> 9     G = ox.graph_from_point(wurster_hall, dist=one_mile, network_type='drive')
#      10     if G is None:
#
# File /opt/conda/lib/python3.10/site-packages/osmnx/graph.py:162, in graph_from_point(center_point, dist, dist_type, network_type, simplify, retain_all, truncate_by_edge, clean_periphery, custom_filter)
#     161 # create a graph from the bounding box
# --> 162 G = graph_from_bbox(
#     163     north,
#     164     south,
#     165     east,
#     166     west,
#     167     network_type=network_type,
#     168     simplify=simplify,
#     169     retain_all=retain_all,
#     170     truncate_by_edge=truncate_by_edge,
#     171     clean_periphery=clean_periphery,
#     172     custom_filter=custom_filter,
#     173 )
#     175 if dist_type == "network":
#     176     # if dist_type is network, find node in graph nearest to center point
#     177     # then truncate graph by network dist from it
#
# File /opt/conda/lib/python3.10/site-packages/osmnx/graph.py:85, in graph_from_bbox(north, south, east, west, network_type, simplify, retain_all, truncate_by_edge, clean_periphery, custom_filter)
#      84 # create graph using this polygon geometry
# ---> 85 G = graph_from_polygon(
#      86     polygon,
#      87     network_type=network_type,
#      88     simplify=simplify,
#      89     retain_all=retain_all,
#      90     truncate_by_edge=truncate_by_edge,
#      91     clean_periphery=clean_periphery,
#      92     custom_filter=custom_filter,
#      93 )
#      95 utils.log(f"graph_from_bbox returned graph with {len(G)} nodes and {len(G.edges)} edges")
#
# File /opt/conda/lib/python3.10/site-packages/osmnx/graph.py:432, in graph_from_polygon(polygon, network_type, simplify, retain_all, truncate_by_edge, clean_periphery, custom_filter)
#     431 # download the network data from OSM within buffered polygon
# --> 432 response_jsons = downloader._osm_network_download(poly_buff, network_type, custom_filter)
#     434 # create buffered graph from the downloaded data
#
# File /opt/conda/lib/python3.10/site-packages/osmnx/downloader.py:548, in _osm_network_download(polygon, network_type, custom_filter)
#     547 query_str = f"{overpass_settings};(way{osm_filter}(poly:'{polygon_coord_str}');>;);out;"
# --> 548 response_json = overpass_request(data={"data": query_str})
#     549 response_jsons.append(response_json)
#
# File /opt/conda/lib/python3.10/site-packages/osmnx/downloader.py:773, in overpass_request(data, pause, error_pause)
#     772 headers = _get_http_headers()
# --> 773 response = requests.post(
#     774     url, data=data, timeout=settings.timeout, headers=headers, **settings.requests_kwargs
#     775 )
#     776 sc = response.status_code
#
# File /opt/conda/lib/python3.10/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     104 r"""Sends a POST request.
#     105
#     106 :param url: URL for the new :class:`Request` object.
#    (...)
#     112 :rtype: requests.Response
#     113 """
# --> 115 return request("post", url, data=data, json=json, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File /opt/conda/lib/python3.10/site-packages/requests/sessions.py:745, in Session.send(self, request, **kwargs)
#     744 if not stream:
# --> 745     r.content
#     747 return r
#
# File /opt/conda/lib/python3.10/site-packages/requests/models.py:900, in Response.content(self)
#     899     else:
# --> 900         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     902 self._content_consumed = True
#
# File /opt/conda/lib/python3.10/site-packages/requests/models.py:819, in Response.iter_content.<locals>.generate()
#     818 except ProtocolError as e:
# --> 819     raise ChunkedEncodingError(e)
#     820 except DecodeError as e:
#
# ChunkedEncodingError: ('Connection broken: IncompleteRead(0 bytes read, 8096 more expected)', IncompleteRead(0 bytes read, 8096 more expected))
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File <timed exec>:2, in <module>
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:8839, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8828 from pandas.core.apply import frame_apply
#    8830 op = frame_apply(
#    8831     self,
#    8832     func=func,
#    (...)
#    8837     kwargs=kwargs,
#    8838 )
# -> 8839 return op.apply().__finalize__(self, method="apply")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/apply.py:727, in FrameApply.apply(self)
#     724 elif self.raw:
#     725     return self.apply_raw()
# --> 727 return self.apply_standard()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/apply.py:851, in FrameApply.apply_standard(self)
#     850 def apply_standard(self):
# --> 851     results, res_index = self.apply_series_generator()
#     853     # wrap results
#     854     return self.wrap_results(results, res_index)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/apply.py:867, in FrameApply.apply_series_generator(self)
#     864 with option_context("mode.chained_assignment", None):
#     865     for i, v in enumerate(series_gen):
#     866         # ignore SettingWithCopy here in case the user mutates
# --> 867         results[i] = self.f(v)
#     868         if isinstance(results[i], ABCSeries):
#     869             # If we have a view on v, we need to make a copy because
#     870             #  series_generator will swap out the underlying data
#     871             results[i] = results[i].copy(deep=False)
#
# Input In [30], in get_stats(data)
#      32     time.sleep(0.5)
#      33     return pd.Series(stats)
# ---> 35 except Error as e:
#      36     print(data)
#      37     print(e)
#
# NameError: name 'Error' is not defined

# %%
len(stats_list)
# Out:
# 1

# %%
target_stations_with_stats = pd.concat([target_stations, stats_list], axis=1)

# %%
target_stations_with_stats.to_csv(f'../../../data/stats/stations_20220926.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [64], in <cell line: 1>()
# ----> 1 target_stations_with_stats.to_csv(f'../../../data/stats/stations_20220926.csv')
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
#    3553     line_terminator=line_terminator,
#    3554     sep=sep,
#    3555     encoding=encoding,
#    3556     errors=errors,
#    3557     compression=compression,
#    3558     quoting=quoting,
#    3559     columns=columns,
#    3560     index_label=index_label,
#    3561     mode=mode,
#    3562     chunksize=chunksize,
#    3563     quotechar=quotechar,
#    3564     date_format=date_format,
#    3565     doublequote=doublequote,
#    3566     escapechar=escapechar,
#    3567     storage_options=storage_options,
#    3568 )
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py:1180, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1159     created_buffer = False
#    1161 csv_formatter = CSVFormatter(
#    1162     path_or_buf=path_or_buf,
#    1163     line_terminator=line_terminator,
#    (...)
#    1178     formatter=self.fmt,
#    1179 )
# -> 1180 csv_formatter.save()
#    1182 if created_buffer:
#    1183     assert isinstance(path_or_buf, StringIO)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.line_terminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/common.py:697, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     695 # Only for write methods
#     696 if "r" not in mode and is_path:
# --> 697     check_parent_directory(str(handle))
#     699 if compression:
#     700     if compression != "zstd":
#     701         # compression libraries do not like an explicit text-mode
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/common.py:571, in check_parent_directory(path)
#     569 parent = Path(path).parent
#     570 if not parent.is_dir():
# --> 571     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '../../../data/stats'

# %%
target_stations_with_stats = pd.read_csv(f'../../../data/stats/stations_20220926.csv')

# %%
target_stations_with_stats

# %%
len(target_stations)

# %%
# 路線ごとの交差点数、道路数のグラフ化
ax = None
colors = {11312: 'red', 24001: 'pink', 25001: 'blue'}
for i, station in target_stations_with_stats.groupby('line_cd'):
    station.plot.scatter(x='n', y='m', color=colors[i], label='cluster{i}', ax=ax)

# %%
chuo_stations = target_stations_with_stats[target_stations_with_stats['line_cd'] == 11312]
keio_stations = target_stations_with_stats[target_stations_with_stats['line_cd'] == 24001]
odakyu_stations = target_stations_with_stats[target_stations_with_stats['line_cd'] == 25001]

# %%
plt.hist([chuo_stations['n'], keio_stations['n']], bins = 20, color=['red', 'pink'])

# %%
plt.hist([chuo_stations['m'], keio_stations['m']], bins = 20, color=['red', 'pink'])

# %%
# k-means法を使うためのインポート
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# データの列の絞り込み
stations_sub = target_stations_with_stats[['n','m']]

# 標準化
sc = StandardScaler()
sc.fit(stations_sub)
stations_sub_std = sc.transform(stations_sub)

# %%
# KMeansクラスの初期化
kmeans = KMeans(init='random', n_clusters=3, random_state=0)

# クラスターの重心を計算
kmeans.fit(stations_sub_std)

# クラスター番号をpandasのSeriesオブジェクトに変換
labels = pd.Series(kmeans.labels_, name='cluster_number', index=target_stations_with_stats.index)

# クラスター番号と件数を表示
print(labels.value_counts(sort=False))

# グラフを描画
ax = labels.value_counts(sort=False).plot(kind='bar')
ax.set_xlabel('cluster number')
ax.set_ylabel('count')

# %%
# エルボー方による推定。クラスター数を1から20に増やして、それぞれの距離の総和を求める
dist_list =[]
for i in range(1,20):
    kmeans= KMeans(n_clusters=i, init='random', random_state=0)
    kmeans.fit(stations_sub_std)
    dist_list.append(kmeans.inertia_)
    
# グラフを表示
plt.plot(range(1,20), dist_list,marker='+')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')

# %%
# 駅のデータにクラスター番号のデータを結合
stations_with_cluster = pd.concat([target_stations_with_stats, pd.Series(labels, index=target_stations_with_stats.index)], axis=1)

# 先頭の5行を表示
stations_with_cluster.head()

# %%
stations_0 = stations_with_cluster[stations_with_cluster['cluster_number'] == 0]
stations_1 = stations_with_cluster[stations_with_cluster['cluster_number'] == 1]
stations_2 = stations_with_cluster[stations_with_cluster['cluster_number'] == 2]
# クラスタリング結果のグラフ化
ax = None
colors = ['red', 'pink', 'blue']
for i, station in stations_with_cluster.groupby('cluster_number'):
    station.plot.scatter(x='n', y='m', color=colors[i], label='cluster{i}', ax=ax)

# %%
# クラスタ番号と年齢層を軸に集計し、年齢層を列に設定
cross_cluster_line_cd = stations_with_cluster.groupby(['cluster_number', 'line_cd']).size().unstack().fillna(0)
cross_cluster_line_cd

# %%
sns.heatmap(cross_cluster_line_cd.apply(lambda x : x/x.sum(), axis=1), cmap='Blues')

# %%
print([station['station_name'] for _, station in stations_with_cluster.iterrows() if (station['cluster_number'] == 0)])

# %%
print([station['station_name'] for _, station in stations_with_cluster.iterrows() if (station['cluster_number'] == 1)])

# %%
print([station['station_name'] for _, station in stations_with_cluster.iterrows() if (station['cluster_number'] == 2)])
