# %%
import numpy as np
import pandas as pd
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
stations = pd.read_csv('../data/stations_kanto.csv')

stations.head(5)
# Out:
#    station_cd  station_g_cd station_name  station_name_k  station_name_r  \
# 0     1130506       1130506          東所沢             NaN             NaN
# 1     1130507       1130507           新座             NaN             NaN
# 2     1130508       1130508          北朝霞             NaN             NaN
# 3     1130509       1130509          西浦和             NaN             NaN
# 4     1130510       1130510         武蔵浦和             NaN             NaN
#
#    line_cd  pref_cd      post           address         lon  ...  \
# 0    11305       11  359-0022          所沢市本郷１丁目  139.513878  ...
# 1    11305       11  352-0011         新座市野火止５丁目  139.556328  ...
# 2    11305       11  351-0033          朝霞市浜崎１丁目  139.587322  ...
# 3    11305       11  338-0837      さいたま市桜区田島５丁目  139.627707  ...
# 4    11305       11  336-0021  さいたま市南区別所七丁目12-1  139.647974  ...
#
#    street_segments_count node_density_km intersection_density_km  \
# 0                  706.0      210.635144              200.261250
# 1                  672.0      212.306961              176.365231
# 2                  879.0      247.449356              220.936925
# 3                  872.0      278.826632              220.477262
# 4                  999.0      272.668926              246.320245
#
#    edge_density_km  street_density_km  circuity_avg  self_loop_proportion  \
# 0     44092.478846       22317.256266      1.033771              0.002147
# 1     36061.846385       18873.557190      1.096247              0.003834
# 2     43252.257861       22209.618128      1.058486              0.001174
# 3     41545.071412       21726.569992      1.042005              0.000000
# 4     45257.298857       23983.223340      1.010927              0.000000
#
#    clean_intersection_count  clean_intersection_density_km  station_name_roman
# 0                     366.0                     165.080220                 NaN
# 1                     277.0                     115.765803                 NaN
# 2                     335.0                     134.570673                 NaN
# 3                     301.0                     125.451145                 NaN
# 4                     418.0                     166.874979                 NaN
#
# [5 rows x 36 columns]

# %%
X_columns = ['n', 'm', 'k_avg', 'intersection_count',
       'streets_per_node_avg', 'edge_length_total', 'edge_length_avg',
       'street_length_total', 'street_length_avg', 'street_segments_count',
       'node_density_km', 'intersection_density_km', 'edge_density_km',
       'street_density_km', 'circuity_avg', 'self_loop_proportion',
       'clean_intersection_count', 'clean_intersection_density_km']

# %%
len(stations)
# Out:
# 2031

# %%
# !pip install mglearn
# Out:
# Collecting mglearn
#   Downloading mglearn-0.1.9.tar.gz (540 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.1/540.1 kB 202.6 kB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from mglearn) (1.22.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from mglearn) (3.5.2)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from mglearn) (1.1.1)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from mglearn) (1.4.2)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from mglearn) (9.1.1)
# Requirement already satisfied: cycler in /opt/conda/lib/python3.10/site-packages (from mglearn) (0.11.0)
# Collecting imageio
#   Downloading imageio-2.21.1-py3-none-any.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 97.1 kB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from mglearn) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mglearn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mglearn) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mglearn) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mglearn) (1.4.3)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mglearn) (4.33.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->mglearn) (2022.1)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->mglearn) (1.8.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->mglearn) (3.1.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mglearn) (1.16.0)
# Building wheels for collected packages: mglearn
#   Building wheel for mglearn (setup.py) ... done
#   Created wheel for mglearn: filename=mglearn-0.1.9-py2.py3-none-any.whl size=582621 sha256=692f8d1b6c63147b061c2f6222bc8ac9e2a61932142ba52c6ebb01887f59fe03
#   Stored in directory: /home/jovyan/.cache/pip/wheels/11/33/5e/10b9333a84e80e0c099acf23ccc525e2607ecad167aa881be9
# Successfully built mglearn
# Installing collected packages: imageio, mglearn
# Successfully installed imageio-2.21.1 mglearn-0.1.9

# %%
from sklearn.preprocessing import StandardScaler

# データ分割
X = stations[X_columns]
X_train = X

#標準化
sc = StandardScaler()
sc.fit(X)
X_std = sc.transform(X)

# %%
# k-means法を使うためのインポート
# from sklearn.cluster import KMeans
# from sklearn.preprocessing import StandardScaler

# hierarchical clusteringを利用するためのモジュールインポート
#階層的クラスタリングはscipyらしい
import mglearn
import scipy.spatial.distance as distance
from scipy.cluster.hierarchy import dendrogram, ward

# %%
#ward法で分類
linkage_array = ward(X_std)
 
ax = plt.figure(figsize=(20,10)).gca()
dendrogram(linkage_array)
bounds = ax.get_xbound()
 
plt.xlabel("sample index",fontsize=10)
plt.ylabel("Cluster distance",fontsize=10)
# Out:
# Text(0, 0.5, 'Cluster distance')

# %%
from scipy.cluster.hierarchy import linkage, fcluster
 
# クラスタ分けするしきい値を決める。4分割したいので60に設定。
threshold = 60
linkage_array = linkage(X_std, method='ward', metric='euclidean')
 
# クラスタリング結果の値を取得
clustered = fcluster(linkage_array, threshold, criterion='distance')

# %%
pd.DataFrame(clustered).describe()
# Out:
#                  0
# count  2031.000000
# mean      2.354998
# std       1.083928
# min       1.000000
# 25%       1.000000
# 50%       2.000000
# 75%       3.000000
# max       4.000000

# %%
# クラスター番号をpandasのSeriesオブジェクトに変換
labels = pd.Series(clustered, name='cluster_number', index=stations.index)

# クラスター番号と件数を表示
print(labels.value_counts(sort=False))

# グラフを描画
ax = labels.value_counts(sort=False).plot(kind='bar')
ax.set_xlabel('cluster number')
ax.set_ylabel('count')
# Out:
# 3    652
# 1    617
# 2    419
# 4    343
# Name: cluster_number, dtype: int64
# Text(0, 0.5, 'count')

# %%
# 駅のデータにクラスター番号のデータを結合
stations_with_cluster = pd.concat([stations, pd.Series(labels, index=stations.index)], axis=1)

# 先頭の5行を表示
stations_with_cluster.head()
# Out:
#    station_cd  station_g_cd station_name  station_name_k  station_name_r  \
# 0     1130506       1130506          東所沢             NaN             NaN
# 1     1130507       1130507           新座             NaN             NaN
# 2     1130508       1130508          北朝霞             NaN             NaN
# 3     1130509       1130509          西浦和             NaN             NaN
# 4     1130510       1130510         武蔵浦和             NaN             NaN
#
#    line_cd  pref_cd      post           address         lon  ...  \
# 0    11305       11  359-0022          所沢市本郷１丁目  139.513878  ...
# 1    11305       11  352-0011         新座市野火止５丁目  139.556328  ...
# 2    11305       11  351-0033          朝霞市浜崎１丁目  139.587322  ...
# 3    11305       11  338-0837      さいたま市桜区田島５丁目  139.627707  ...
# 4    11305       11  336-0021  さいたま市南区別所七丁目12-1  139.647974  ...
#
#    node_density_km intersection_density_km edge_density_km  street_density_km  \
# 0       210.635144              200.261250    44092.478846       22317.256266
# 1       212.306961              176.365231    36061.846385       18873.557190
# 2       247.449356              220.936925    43252.257861       22209.618128
# 3       278.826632              220.477262    41545.071412       21726.569992
# 4       272.668926              246.320245    45257.298857       23983.223340
#
#    circuity_avg  self_loop_proportion  clean_intersection_count  \
# 0      1.033771              0.002147                     366.0
# 1      1.096247              0.003834                     277.0
# 2      1.058486              0.001174                     335.0
# 3      1.042005              0.000000                     301.0
# 4      1.010927              0.000000                     418.0
#
#    clean_intersection_density_km  station_name_roman  cluster_number
# 0                     165.080220                 NaN               3
# 1                     115.765803                 NaN               3
# 2                     134.570673                 NaN               1
# 3                     125.451145                 NaN               1
# 4                     166.874979                 NaN               1
#
# [5 rows x 37 columns]

# %%
labels.value_counts()
# Out:
# 3    652
# 1    617
# 2    419
# 4    343
# Name: cluster_number, dtype: int64

# %%
stations_1 = stations_with_cluster[stations_with_cluster['cluster_number'] == 1]
stations_2 = stations_with_cluster[stations_with_cluster['cluster_number'] == 2]
stations_3 = stations_with_cluster[stations_with_cluster['cluster_number'] == 3]
stations_4 = stations_with_cluster[stations_with_cluster['cluster_number'] == 4]
# クラスタリング結果のグラフ化
ax = None
colors = ['red', 'pink', 'blue', 'green']
for i, station in stations_with_cluster.groupby('cluster_number'):
    station.plot.scatter(x='circuity_avg', y='streets_per_node_avg', color=colors[i - 1], label='cluster{i}', ax=ax)

# %%
import folium
center_lat, center_lon = (35.651820534474,139.54461236426)

_map = folium.Map(location=[center_lat, center_lon], zoom_start=11)

for _, station in stations_with_cluster.iterrows():
    color = 'pink' if station['cluster_number'] == 1 else 'blue' if station['cluster_number'] == 2 else 'red' if station['cluster_number'] == 3 else 'green' if station['cluster_number'] == 4 else 'orange'
    folium.Marker([station.lat, station.lon], popup=str(station['station_name_roman']), icon=folium.Icon(color=color)).add_to(_map)

_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_10789f90f702d97e6442134b661ae97e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_10789f90f702d97e6442134b661ae97e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_10789f90f702d97e6442134b661ae97e = L.map(
#                 &quot;map_10789f90f702d97e6442134b661ae97e&quot;,
#                 {
#                     center: [35.651820534474, 139.54461236426],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f883126f133f4aa71f881c25e97e13bb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_10789f90f702d97e6442134b661ae97e);
#
#
#             var marker_eedef0b49fb55b1c7644a7df90cab685 = L.marker(
#                 [35.79461, 139.513878],
#                 {}
#             ).addTo(map_10789f90f702d97e6442134b661ae97e);
#
#
#             var icon_c1ba89078ab20170f77e47b817ba619c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_eedef0b49fb55b1c7644a7df90cab685.setIcon(icon_c1ba89078ab20170f77e47b817ba619c);
#
#
#         var popup_3624af105cd92845f6c50056fbc14da7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_88650e8530cd1a74a59e53ea8b17c139 = $(`&lt;div id=&quot;html_88650e8530cd1a74a59e53ea8b17c139&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;nan&lt;/div&gt;`)[0];
#             popup_3624af105cd92845f6c50056fbc14da7.setContent(html_88650e8530cd1a74a59e53ea8b17c139);
#
#
#         marker_eedef0b49fb55b1c7644a7df90cab685.bindPopup(popup_3624af105cd92845f6c50056fbc14da7)
#         ;
#
#
#
#
#             var marker_e1c207cd8af3f72ebba34a54e42e2cc9 = L.marker(
#                 [35.80381, 139.556328],
#                 {}
#             ).addTo(map_10789f90f702d97e6442134b661ae97e);
#
#
#             var icon_6aaae570942ac8c458575acb448c4a20 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e1c207cd8af3f72ebba34a54e42e2cc9.setIcon(icon_6aaae570942ac8c458575acb448c4a20);
#
#
#         var popup_0893515f75fcbdc1dd5afdc76e0254b3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_962459e93b420fef4aa4202662b0c3cd = $(`&lt;div id=&quot;html_962459e93b420fef4aa4202662b0c3cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;nan&lt;/div&gt;`)[0];
#             popup_0893515f75fcbdc1dd5afdc76e0254b3.setContent(html_962459e93b420fef4aa4202662b0c3cd);
#
#
#         marker_e1c207cd8af3f72ebba34a54e42e2cc9.bindPopup(popup_0893515f75fcbdc1dd5afdc76e0254b3)
#         ;
#
#
#
#
#             var marker_824222d4498de965bbd1307b662ad7e3 = L.marker(
#                 [35.815475, 139.587322],
#                 {}
#             ).addTo(map_10789f90f702d97e6442134b661ae97e);
#
#
#             var icon_ab5f69edfb280eb96f188fe08af9fe29 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_824222d4498de965bbd1307b662ad7e3.setIcon(icon_ab5f69edfb280eb96f188fe08af9fe29);
#
#
#         var popup_1f7675146bd957dc839ab10bdcfe85a8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_18ed75188f97ea11b7dc8ffbc9b30ff9 = $(`&lt;div id=&quot;html_18ed75188f97ea11b7dc8ffbc9b30ff9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;nan&lt;/div&gt;`)[0];
#             popup_1f7675146bd957dc839ab10bdcfe85a8.setContent(html_18ed75188f97ea11b7dc8ffbc9b30ff9);
#
#
#         marker_824222d4498de965bbd1307b662ad7e3.bindPopup(popup_1f7675146bd957dc839ab10bdcfe85a8)
#         ;
#
#
#
#
#             var marker_64c89cf762bf65ac32f34a70dd82f79a = L.marker(
#                 [35.844139, 139.627707],
#                 {}
#             ).addTo(map_10789f90f702d97e6442134b661ae97e);
#
#
#             var icon_683b46b7b1914b1516881b6e9ca9beb1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_64c89cf762bf65ac32f34a70dd82f79a.setIcon(icon_683b46b7b1914b1516881b6e9ca9beb1);

# %%
stations_with_cluster.to_csv('./stations_with_hierarchical_cluster_4_without_pca.csv', index=False)

# %%
stations_with_cluster = pd.read_csv('./stations_with_hierarchical_cluster_4_without_pca.csv')

# %%
stations_1 = stations_with_cluster[stations_with_cluster['cluster_number'] == 2] # group1 
stations_2 = stations_with_cluster[stations_with_cluster['cluster_number'] == 1] # group2
stations_3 = stations_with_cluster[stations_with_cluster['cluster_number'] == 3] # group3
stations_4 = stations_with_cluster[stations_with_cluster['cluster_number'] == 4] # group4

# %%
# クラスタリング結果のグラフ化
ax = None
colors = ['green', 'red', 'pink', 'blue']
for i, station in stations_with_cluster.groupby('cluster_number'):
    station.plot.scatter(x='circuity_avg', y='streets_per_node_avg', color=colors[i - 1], label='cluster{i}', ax=ax)
